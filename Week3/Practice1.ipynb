# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pymannkendall as mk

# %%
pip install pymannkendall
# Out:
# Collecting pymannkendall
#   Downloading pymannkendall-1.4.3-py3-none-any.whl (12 kB)
# Requirement already satisfied: scipy in c:\users\dell\anaconda3\lib\site-packages (from pymannkendall) (1.10.1)
# Requirement already satisfied: numpy in c:\users\dell\anaconda3\lib\site-packages (from pymannkendall) (1.24.3)
# Installing collected packages: pymannkendall
# Successfully installed pymannkendall-1.4.3
# Note: you may need to restart the kernel to use updated packages.

# %%
data = [54, 52, 53, 59, 56, 57, 51, 52, 50, 53]

# perform Mann-Kendall Trend Test
mk.original_test(data)
# Out:
# Mann_Kendall_Test(trend='no trend', h=False, p=0.3672323880406272, z=-0.9016696346674322, Tau=-0.24444444444444444, s=-11.0, var_s=123.0, slope=-0.2857142857142857, intercept=54.285714285714285)

# %%
plt.plot(data)

# %%
data = [1, 2, 3, 4, 5]

# perform Mann-Kendall Trend Test
mk.original_test(data)
# Out:
# Mann_Kendall_Test(trend='increasing', h=True, p=0.0274863361115103, z=2.2045407685048604, Tau=1.0, s=10.0, var_s=16.666666666666668, slope=1.0, intercept=1.0)

# %%
plt.plot(data)

# %%
t = np.linspace(0, 5, 100)
x = t + np.random.normal(size=100)

# %%
plt.plot(x)

# %%
from scipy import signal
x_detrended = signal.detrend(x)

# %%
plt.plot(x_detrended)
